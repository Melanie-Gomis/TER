# %% [markdown]
# Ce notebook a été entièrement réalisé par Mélnaie Gomis.

# %% [markdown]
# # ViT

# %%
# Installation de gdown si besoin
try:
    import gdown
except ImportError:
    # %pip install -q gdown
    import gdown

# %%
import numpy as np
import glob
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import gdown
import matplotlib.pyplot as plt

# %% [markdown]
# # Chargement des données

# %%
"""
    os.chdir("../Données")
    fichiers_npz = glob.glob('*.npz')
    cosmos_files = [f for f in fichiers_npz if "COSMOS" in f]
"""
# Out:
# '\n    os.chdir("../Données")\n    fichiers_npz = glob.glob(\'*.npz\')\n    cosmos_files = [f for f in fichiers_npz if "COSMOS" in f]\n'

# %%
# On définit le nom du dossier
dossier_nom = "redshift"
url = "https://drive.google.com/drive/folders/1-tQH6rfB1XoF7ml98yqVn7Z2IQwGMUdK?usp=sharing"

# 2. LOGIQUE DE TÉLÉCHARGEMENT
if os.path.exists(dossier_nom):
    print(f"✅ Le dossier '{dossier_nom}' est déjà présent. Pas besoin de retélécharger !")
else:
    print(f"📥 Dossier introuvable. Téléchargement en cours...")
    gdown.download_folder(url, quiet=True, use_cookies=False)
    print("✅ Téléchargement terminé !")

# 3. CRÉATION DE LA LISTE DES FICHIERS (C'est ici que ça plantait avant)
# On scanne le dossier pour créer la liste 'dossier_local' quoi qu'il arrive
pattern = os.path.join(dossier_nom, "*") # ex: redshift/*
dossier_local = glob.glob(pattern)

# 4. AFFICHAGE JOLI
print(f"\nSuccès ! {len(dossier_local)} fichiers trouvés dans '{dossier_nom}'.")
print("Détail des fichiers :")

for chemin in dossier_local:
    # On extrait le nom du dossier et le nom du fichier
    dossier = os.path.dirname(chemin)   # ex: redshift
    fichier = os.path.basename(chemin)  # ex: COSMOS_...npz
    
    # Ton format demandé
    print(f"[{dossier}] :\t {fichier}")
# Out:
# ✅ Le dossier 'redshift' est déjà présent. Pas besoin de retélécharger !
#
# Succès ! 16 fichiers trouvés dans 'redshift'.
# Détail des fichiers :
# [redshift] :	 info4.csv
# [redshift] :	 output_zphot_only.txt
# [redshift] :	 info3.csv
# [redshift] :	 COSMOS_v11_uijk_0020_spec_D.npz
# [redshift] :	 cnn_architecture.png
# [redshift] :	 info2.csv
# [redshift] :	 COSMOS_v11_uijk_0001_photo_D.npz
# [redshift] :	 COSMOS_v11_uijk_0073_spec_UD.npz
# [redshift] :	 COSMOS_v11_uijk_0213_photo_UD.npz
# [redshift] :	 XMM_LSS_v11_uijk_0006_spec_D.npz
# [redshift] :	 best_photoz_model.pt
# [redshift] :	 cnn_photoz_model.h5
# [redshift] :	 XMM_LSS_v11_uijk_0162_phot_UD.npz
# [redshift] :	 info.csv
# [redshift] :	 XMM_LSS_v11_uijk_0162_phot_D.npz
# [redshift] :	 tmp_csv

# %%
fichiers_npz = glob.glob('redshift/*.npz')
cosmos_files = [f for f in fichiers_npz if "COSMOS" in f]

# Listes séparées pour train et test
train_cubes_list = []
train_infos_list = []
train_flag_list = []

test_cubes_list = []
test_infos_list = []
test_flag_list = []

print(f"Chargement de {len(cosmos_files)} fichiers COSMOS.")

for fichier in cosmos_files:
    try:
        data = np.load(fichier, allow_pickle=True)
        
        # 'info' est un array structuré. 'dtype.names' donne les noms des colonnes.
        info_fields = data['info'].dtype.names
        
        # On vérifie si la *colonne* 'ZSPEC' existe dans ce fichier
        if 'ZSPEC' in info_fields:
            # Ce fichier contient des données de TEST (il a la colonne ZSPEC)
            test_cubes_list.append(data['cube'])
            test_infos_list.append(data['info'])
            test_flag_list.append(data['flag'])
        else:
            # Ce fichier contient des données de TRAIN (pas de colonne ZSPEC)
            train_cubes_list.append(data['cube'])
            train_infos_list.append(data['info'])
            train_flag_list.append(data['flag'])
            
            
    except Exception as e:
        print(f":x: Erreur en chargeant {fichier}: {e}")

print("Chargement terminé.")
# Out:
# Chargement de 4 fichiers COSMOS.
# Chargement terminé.

# %%
# Création des jeux train/test

# Jeu d’entraînement (basé sur les fichiers SANS ZSPEC)
# On vérifie qu'on a bien trouvé des fichiers de train
if train_infos_list:
    X_train = np.concatenate(train_cubes_list, axis=0)
    infos_train = np.concatenate(train_infos_list, axis=0)
    flags_train = np.concatenate(train_flag_list, axis=0)
    y_train = infos_train['ZPHOT'] # Obtenir ZPHOT depuis les infos de train
    print(f"Objets d'entraînement (ZPHOT) : {len(y_train)}")
    print("X_train :", X_train.shape)
    print("y_train :", y_train.shape)
else:
    print("Aucun fichier d'entraînement (sans ZSPEC) trouvé.")

print("\n---\n")

# Jeu de test (basé sur les fichiers AVEC ZSPEC)
# On vérifie qu'on a bien trouvé des fichiers de test
if test_infos_list:
    X_test = np.concatenate(test_cubes_list, axis=0)
    infos_test = np.concatenate(test_infos_list, axis=0)
    flags_test = np.concatenate(test_flag_list, axis=0)
    y_test = infos_test['ZSPEC'] # Obtenir ZSPEC depuis les infos de test

    # Si on ne garde que les ZSPEC valides
    # mask_zspec_valid = ~np.isnan(y_test) ou ???
    # X_test = X_test[mask_zspec_valid]
    # y_test = y_test[mask_zspec_valid]

    print(f"Objets de test (ZSPEC) : {len(y_test)}")
    print("X_test  :", X_test.shape)
    print("y_test  :", y_test.shape)
else:
    print("Aucun fichier de test (avec ZSPEC) trouvé.")
# Out:
# Objets d'entraînement (ZPHOT) : 12497
# X_train : (12497, 64, 64, 9)
# y_train : (12497,)
#
# ---
#
# Objets de test (ZSPEC) : 27
# X_test  : (27, 64, 64, 9)
# y_test  : (27,)

# %% [markdown]
# # Encodeur d’images (Image Encoder)

# %% [markdown]
# On veut des patchs précis mais pas trop lourd.
#
# - Patch embedding
#     - On utilisera des patchs de 16x16 feront l'affaire.
#     - La projection se fera dans un embedding dimension de 512.
# - Transformers
#     - On prendre 7 couches et 8 têtes (car 512 / 64 = 8).

# %%
X_train_tensor = torch.tensor(np.ascontiguousarray(X_train), dtype=torch.float32)
y_train_tensor = torch.tensor(np.ascontiguousarray(y_train), dtype=torch.float32).unsqueeze(1)

X_test_tensor = torch.tensor(np.ascontiguousarray(X_test), dtype=torch.float32)
y_test_tensor = torch.tensor(np.ascontiguousarray(y_test), dtype=torch.float32).unsqueeze(1)

# %%
batch_size = 32

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# --- Patch Embedding ---
class PatchEmbedding(nn.Module):
    def __init__(self, img_size=64, patch_size=16, in_channels=9, embed_dim=512):
        super().__init__()
        self.patch_size = patch_size
        self.n_patches = (img_size // patch_size) ** 2
        self.proj = nn.Linear(patch_size * patch_size * in_channels, embed_dim)
        self.cls_token = nn.Parameter(torch.randn(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.randn(1, self.n_patches + 1, embed_dim))

    def forward(self, x):
        B, H, W, C = x.shape
        patches = x.unfold(1, self.patch_size, self.patch_size) \
                   .unfold(2, self.patch_size, self.patch_size)
        patches = patches.contiguous().view(B, -1, self.patch_size * self.patch_size*C)
        patches = self.proj(patches)
        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, patches), dim=1)
        x = x + self.pos_embed
        return x

# --- Transformer Block ---
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim=512, num_heads=8, mlp_dim=2048, dropout=0.1):
        super().__init__()
        self.ln1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads, dropout=dropout)
        self.ln2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.GELU(),
            nn.Linear(mlp_dim, embed_dim)
        )

    def forward(self, x):
        x_ = self.ln1(x)
        x_attn, _ = self.attn(x_, x_, x_)
        x = x + x_attn
        x = x + self.mlp(self.ln2(x))
        return x

# --- ViT Image Encoder ---
class ViTImageEncoder(nn.Module):
    def __init__(self, img_size=64, patch_size=16, in_channels=9, embed_dim=512,
                 depth=7, num_heads=8, mlp_dim=2048):
        super().__init__()
        self.patch_embed = PatchEmbedding(img_size, patch_size, in_channels, embed_dim)
        self.transformer_blocks = nn.ModuleList([
            TransformerBlock(embed_dim, num_heads, mlp_dim) for _ in range(depth)
        ])
        self.ln = nn.LayerNorm(embed_dim)

    def forward(self, x):
        x = self.patch_embed(x)
        x = x.permute(1, 0, 2)  # seq_len, batch, embed_dim
        for blk in self.transformer_blocks:
            x = blk(x)
        x = x.permute(1, 0, 2)  # batch, seq_len, embed_dim
        x = self.ln(x)
        cls_embedding = x[:, 0, :]
        return cls_embedding

# %%
""" class ParamMLP(nn.Module): 
    def __init__(self, input_dim=1, embed_dim=512):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, embed_dim),
            nn.ReLU(),
            nn.Linear(embed_dim, embed_dim)
        )
        
    def forward(self, x):
        return self.fc(x)
 """

# %%
class ViTRegressor(nn.Module):
    def __init__(self, img_size=64, patch_size=16, in_channels=9,
                 embed_dim=512, depth=7, num_heads=8, mlp_dim=2048):
        super().__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer

        # ViT encodeur
        self.vit = ViTImageEncoder(img_size, patch_size, in_channels,
                                   embed_dim, depth, num_heads, mlp_dim)
        
        # couche finale pour prédire ZPHOT
        self.regressor = nn.Linear(embed_dim, 1)
        
    def forward(self, x):
        embedding = self.vit(x)  # B, 512
        zphot_pred = self.regressor(embedding)  # B,1
        return zphot_pred

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = ViTRegressor().to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# Une époque prends environs 13.25 secondes avec les GPU T4 de Google Colab.

# %%
num_epochs = 200 # augmenter si nécessaire
tps = 13.25
tps_approx = tps * num_epochs


# Conversion des secondes en jours, heures et minutes
jours = tps_approx // (24 * 3600)
tps_approx %= (24 * 3600)
heures = tps_approx // 3600
tps_approx %= 3600
minutes = tps_approx // 60
secondes = tps_approx % 60


# Affichage
print(f"Temps approximatif : {int(jours)} J {int(heures)} h {int(minutes)} min")
# Out:
# Temps approximatif : 0 J 0 h 44 min

# %%
train_losses = []
test_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * xb.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}")
    
    # évaluation rapide sur test
    model.eval()
    with torch.no_grad():
        test_loss = 0.0
        for xb, yb in test_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            test_loss += criterion(pred, yb).item() * xb.size(0)
        test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print(f"Test Loss: {test_loss:.4f}\n")
# Out:
# Epoch 1/200, Train Loss: 0.7735
# Test Loss: 2.5668
#
# Epoch 2/200, Train Loss: 0.6154
# Test Loss: 2.2312
#
# Epoch 3/200, Train Loss: 0.5631
# Test Loss: 2.1352
#
# Epoch 4/200, Train Loss: 0.5409
# Test Loss: 2.3510
#
# Epoch 5/200, Train Loss: 0.5084
# Test Loss: 2.5589
#
# Epoch 6/200, Train Loss: 0.4768
# Test Loss: 2.0330
#
# Epoch 7/200, Train Loss: 0.4410
# Test Loss: 2.9845
#
# Epoch 8/200, Train Loss: 0.4178
# Test Loss: 2.6630
#
# Epoch 9/200, Train Loss: 0.3986
# Test Loss: 3.2617
#
# Epoch 10/200, Train Loss: 0.3700
# Test Loss: 3.4567
#
# Epoch 11/200, Train Loss: 0.3507
# Test Loss: 3.2278
#
# Epoch 12/200, Train Loss: 0.3314
# Test Loss: 3.2269
#
# Epoch 13/200, Train Loss: 0.3151
# Test Loss: 3.7711
#
# Epoch 14/200, Train Loss: 0.3078
# Test Loss: 3.2849
#
# Epoch 15/200, Train Loss: 0.2931
# Test Loss: 3.1386
#
# Epoch 16/200, Train Loss: 0.2667
# Test Loss: 3.5274
#
# Epoch 17/200, Train Loss: 0.2625
# Test Loss: 3.0844
#
# Epoch 18/200, Train Loss: 0.2455
# Test Loss: 3.7791
#
# Epoch 19/200, Train Loss: 0.2269
# Test Loss: 4.4711
#
# Epoch 20/200, Train Loss: 0.2314
# Test Loss: 3.4352
#
# Epoch 21/200, Train Loss: 0.2411
# Test Loss: 3.1488
#
# Epoch 22/200, Train Loss: 0.2128
# Test Loss: 3.9292
#
# Epoch 23/200, Train Loss: 0.2054
# Test Loss: 3.8202
#
# Epoch 24/200, Train Loss: 0.1946
# Test Loss: 3.6882
#
# Epoch 25/200, Train Loss: 0.1925
# Test Loss: 4.2000
#
# Epoch 26/200, Train Loss: 0.1935
# Test Loss: 3.3037
#
# Epoch 27/200, Train Loss: 0.1684
# Test Loss: 4.7672
#
# Epoch 28/200, Train Loss: 0.1747
# Test Loss: 4.1474
#
# Epoch 29/200, Train Loss: 0.1727
# Test Loss: 4.4058
#
# Epoch 30/200, Train Loss: 0.1722
# Test Loss: 3.6132
#
# Epoch 31/200, Train Loss: 0.1508
# Test Loss: 3.8802
#
# Epoch 32/200, Train Loss: 0.1511
# Test Loss: 3.4826
#
# Epoch 33/200, Train Loss: 0.1495
# Test Loss: 4.1481
#
# Epoch 34/200, Train Loss: 0.1422
# Test Loss: 3.7569
#
# Epoch 35/200, Train Loss: 0.1423
# Test Loss: 2.9540
#
# Epoch 36/200, Train Loss: 0.1396
# Test Loss: 3.2400
#
# Epoch 37/200, Train Loss: 0.1330
# Test Loss: 3.3428
#
# Epoch 38/200, Train Loss: 0.1145
# Test Loss: 2.6627
#
# Epoch 39/200, Train Loss: 0.1045
# Test Loss: 2.7839
#
# Epoch 40/200, Train Loss: 0.1048
# Test Loss: 2.7269
#
# Epoch 41/200, Train Loss: 0.1358
# Test Loss: 3.0399
#
# Epoch 42/200, Train Loss: 0.1305
# Test Loss: 3.5712
#
# Epoch 43/200, Train Loss: 0.1232
# Test Loss: 3.3707
#
# Epoch 44/200, Train Loss: 0.1039
# Test Loss: 3.4046
#
# Epoch 45/200, Train Loss: 0.0998
# Test Loss: 2.9552
#
# Epoch 46/200, Train Loss: 0.1010
# Test Loss: 3.3122
#
# Epoch 47/200, Train Loss: 0.0860
# Test Loss: 3.0107
#
# Epoch 48/200, Train Loss: 0.1012
# Test Loss: 3.1201
#
# Epoch 49/200, Train Loss: 0.0913
# Test Loss: 2.6049
#
# Epoch 50/200, Train Loss: 0.0956
# Test Loss: 2.7667
#
# Epoch 51/200, Train Loss: 0.0967
# Test Loss: 3.4004
#
# Epoch 52/200, Train Loss: 0.0940
# Test Loss: 3.1907
#
# Epoch 53/200, Train Loss: 0.0973
# Test Loss: 2.5744
#
# Epoch 54/200, Train Loss: 0.1043
# Test Loss: 2.7239
#
# Epoch 55/200, Train Loss: 0.1093
# Test Loss: 3.2135
#
# Epoch 56/200, Train Loss: 0.0835
# Test Loss: 2.5669
#
# Epoch 57/200, Train Loss: 0.1004
# Test Loss: 2.9989
#
# Epoch 58/200, Train Loss: 0.0709
# Test Loss: 2.8709
#
# Epoch 59/200, Train Loss: 0.0678
# Test Loss: 3.1739
#
# Epoch 60/200, Train Loss: 0.0631
# Test Loss: 3.0133
#
# Epoch 61/200, Train Loss: 0.0574
# Test Loss: 3.0818
#
# Epoch 62/200, Train Loss: 0.0661
# Test Loss: 2.9448
#
# Epoch 63/200, Train Loss: 0.1216
# Test Loss: 3.1457
#
# Epoch 64/200, Train Loss: 0.0927
# Test Loss: 2.8776
#
# Epoch 65/200, Train Loss: 0.0798
# Test Loss: 3.3525
#
# Epoch 66/200, Train Loss: 0.0650
# Test Loss: 2.9089
#
# Epoch 67/200, Train Loss: 0.1231
# Test Loss: 2.6068
#
# Epoch 68/200, Train Loss: 0.0752
# Test Loss: 2.4783
#
# Epoch 69/200, Train Loss: 0.0572
# Test Loss: 2.4387
#
# Epoch 70/200, Train Loss: 0.0602
# Test Loss: 2.4260
#
# Epoch 71/200, Train Loss: 0.0761
# Test Loss: 2.3433
#
# Epoch 72/200, Train Loss: 0.0879
# Test Loss: 2.2556
#
# Epoch 73/200, Train Loss: 0.0698
# Test Loss: 2.5059
#
# Epoch 74/200, Train Loss: 0.0827
# Test Loss: 2.5597
#
# Epoch 75/200, Train Loss: 0.0629
# Test Loss: 2.3888
#
# Epoch 76/200, Train Loss: 0.0615
# Test Loss: 2.7069
#
# Epoch 77/200, Train Loss: 0.0529
# Test Loss: 3.0010
#
# Epoch 78/200, Train Loss: 0.0563
# Test Loss: 2.8134
#
# Epoch 79/200, Train Loss: 0.0534
# Test Loss: 2.7319
#
# Epoch 80/200, Train Loss: 0.0647
# Test Loss: 2.4459
#
# Epoch 81/200, Train Loss: 0.0756
# Test Loss: 2.5491
#
# Epoch 82/200, Train Loss: 0.0643
# Test Loss: 2.9259
#
# Epoch 83/200, Train Loss: 0.0534
# Test Loss: 2.3323
#
# Epoch 84/200, Train Loss: 0.0418
# Test Loss: 2.4774
#
# Epoch 85/200, Train Loss: 0.0399
# Test Loss: 2.2200
#
# Epoch 86/200, Train Loss: 0.0597
# Test Loss: 2.4127
#
# Epoch 87/200, Train Loss: 0.0419
# Test Loss: 2.3931
#
# Epoch 88/200, Train Loss: 0.0522
# Test Loss: 2.9471
#
# Epoch 89/200, Train Loss: 0.0757
# Test Loss: 3.1608
#
# Epoch 90/200, Train Loss: 0.0490
# Test Loss: 2.9851
#
# Epoch 91/200, Train Loss: 0.0400
# Test Loss: 3.0191
#
# Epoch 92/200, Train Loss: 0.0431
# Test Loss: 2.7875
#
# Epoch 93/200, Train Loss: 0.0786
# Test Loss: 3.3384
#
# Epoch 94/200, Train Loss: 0.0884
# Test Loss: 2.6617
#
# Epoch 95/200, Train Loss: 0.0662
# Test Loss: 2.7488
#
# Epoch 96/200, Train Loss: 0.0547
# Test Loss: 4.6620
#
# Epoch 97/200, Train Loss: 0.0563
# Test Loss: 3.3755
#
# Epoch 98/200, Train Loss: 0.0435
# Test Loss: 3.5380
#
# Epoch 99/200, Train Loss: 0.0505
# Test Loss: 3.3109
#
# Epoch 100/200, Train Loss: 0.0893
# Test Loss: 3.0798
#
# Epoch 101/200, Train Loss: 0.0642
# Test Loss: 3.0799
#
# Epoch 102/200, Train Loss: 0.0486
# Test Loss: 2.7844
#
# Epoch 103/200, Train Loss: 0.0567
# Test Loss: 3.3694
#
# Epoch 104/200, Train Loss: 0.0400
# Test Loss: 2.8100
#
# Epoch 105/200, Train Loss: 0.0345
# Test Loss: 2.7456
#
# Epoch 106/200, Train Loss: 0.0291
# Test Loss: 2.4752
#
# Epoch 107/200, Train Loss: 0.0338
# Test Loss: 2.6463
#
# Epoch 108/200, Train Loss: 0.0509
# Test Loss: 2.7040
#
# Epoch 109/200, Train Loss: 0.0406
# Test Loss: 2.5085
#
# Epoch 110/200, Train Loss: 0.0304
# Test Loss: 2.5268
#
# Epoch 111/200, Train Loss: 0.0286
# Test Loss: 2.3726
#
# Epoch 112/200, Train Loss: 0.0253
# Test Loss: 2.6526
#
# Epoch 113/200, Train Loss: 0.0346
# Test Loss: 2.8603
#
# Epoch 114/200, Train Loss: 0.0896
# Test Loss: 2.8242
#
# Epoch 115/200, Train Loss: 0.0685
# Test Loss: 2.8567
#
# Epoch 116/200, Train Loss: 0.0397
# Test Loss: 2.6063
#
# Epoch 117/200, Train Loss: 0.0289
# Test Loss: 2.6021
#
# Epoch 118/200, Train Loss: 0.0254
# Test Loss: 2.7024
#
# Epoch 119/200, Train Loss: 0.0237
# Test Loss: 2.5909
#
# Epoch 120/200, Train Loss: 0.0218
# Test Loss: 2.6646
#
# Epoch 121/200, Train Loss: 0.0245
# Test Loss: 3.0026
#
# Epoch 122/200, Train Loss: 0.0663
# Test Loss: 3.0075
#
# Epoch 123/200, Train Loss: 0.0898
# Test Loss: 2.5213
#
# Epoch 124/200, Train Loss: 0.1015
# Test Loss: 3.5425
#
# Epoch 125/200, Train Loss: 0.1092
# Test Loss: 2.6933
#
# Epoch 126/200, Train Loss: 0.0600
# Test Loss: 2.6324
#
# Epoch 127/200, Train Loss: 0.0417
# Test Loss: 2.8426
#
# Epoch 128/200, Train Loss: 0.0307
# Test Loss: 2.6882
#
# Epoch 129/200, Train Loss: 0.0297
# Test Loss: 2.7339
#
# Epoch 130/200, Train Loss: 0.0283
# Test Loss: 2.7859
#
# Epoch 131/200, Train Loss: 0.0277
# Test Loss: 2.5709
#
# Epoch 132/200, Train Loss: 0.0239
# Test Loss: 2.7338
#
# Epoch 133/200, Train Loss: 0.0246
# Test Loss: 2.6186
#
# Epoch 134/200, Train Loss: 0.0419
# Test Loss: 2.4297
#
# Epoch 135/200, Train Loss: 0.0950
# Test Loss: 2.8121
#
# Epoch 136/200, Train Loss: 0.0650
# Test Loss: 2.7473
#
# Epoch 137/200, Train Loss: 0.0353
# Test Loss: 2.6049
#
# Epoch 138/200, Train Loss: 0.0447
# Test Loss: 2.5850
#
# Epoch 139/200, Train Loss: 0.0369
# Test Loss: 2.4359
#
# Epoch 140/200, Train Loss: 0.0344
# Test Loss: 2.3848
#
# Epoch 141/200, Train Loss: 0.0406
# Test Loss: 2.3329
#
# Epoch 142/200, Train Loss: 0.0677
# Test Loss: 2.3295
#
# Epoch 143/200, Train Loss: 0.0910
# Test Loss: 2.3524
#
# Epoch 144/200, Train Loss: 0.0560
# Test Loss: 2.2271
#
# Epoch 145/200, Train Loss: 0.0368
# Test Loss: 2.3854
#
# Epoch 146/200, Train Loss: 0.0265
# Test Loss: 2.2877
#
# Epoch 147/200, Train Loss: 0.0700
# Test Loss: 2.4073
#
# Epoch 148/200, Train Loss: 0.0360
# Test Loss: 2.2227
#
# Epoch 149/200, Train Loss: 0.0298
# Test Loss: 2.2913
#
# Epoch 150/200, Train Loss: 0.0292
# Test Loss: 2.4968
#
# Epoch 151/200, Train Loss: 0.0277
# Test Loss: 2.2477
#
# Epoch 152/200, Train Loss: 0.0497
# Test Loss: 2.5944
#
# Epoch 153/200, Train Loss: 0.0710
# Test Loss: 2.3486
#
# Epoch 154/200, Train Loss: 0.0383
# Test Loss: 2.7057
#
# Epoch 155/200, Train Loss: 0.0280
# Test Loss: 2.7902
#
# Epoch 156/200, Train Loss: 0.0226
# Test Loss: 2.5643
#
# Epoch 157/200, Train Loss: 0.0315
# Test Loss: 2.7740
#
# Epoch 158/200, Train Loss: 0.0331
# Test Loss: 2.8050
#
# Epoch 159/200, Train Loss: 0.0483
# Test Loss: 2.5204
#
# Epoch 160/200, Train Loss: 0.0383
# Test Loss: 2.5532
#
# Epoch 161/200, Train Loss: 0.0339
# Test Loss: 2.4607
#
# Epoch 162/200, Train Loss: 0.0275
# Test Loss: 2.5586
#
# Epoch 163/200, Train Loss: 0.0229
# Test Loss: 2.8028
#
# Epoch 164/200, Train Loss: 0.0247
# Test Loss: 2.7725
#
# Epoch 165/200, Train Loss: 0.0278
# Test Loss: 2.6365
#
# Epoch 166/200, Train Loss: 0.0232
# Test Loss: 2.5402
#
# Epoch 167/200, Train Loss: 0.0187
# Test Loss: 2.5262
#
# Epoch 168/200, Train Loss: 0.0177
# Test Loss: 2.4515
#
# Epoch 169/200, Train Loss: 0.0162
# Test Loss: 2.4564
#
# Epoch 170/200, Train Loss: 0.0399
# Test Loss: 3.1402
#
# Epoch 171/200, Train Loss: 0.0713
# Test Loss: 2.4243
#
# Epoch 172/200, Train Loss: 0.0437
# Test Loss: 2.5382
#
# Epoch 173/200, Train Loss: 0.0267
# Test Loss: 2.3856
#
# Epoch 174/200, Train Loss: 0.0280
# Test Loss: 2.6302
#
# Epoch 175/200, Train Loss: 0.0198
# Test Loss: 2.2757
#
# Epoch 176/200, Train Loss: 0.0235
# Test Loss: 2.3901
#
# Epoch 177/200, Train Loss: 0.0625
# Test Loss: 2.7543
#
# Epoch 178/200, Train Loss: 0.0293
# Test Loss: 2.5798
#
# Epoch 179/200, Train Loss: 0.0217
# Test Loss: 2.5950
#
# Epoch 180/200, Train Loss: 0.0182
# Test Loss: 2.6947
#
# Epoch 181/200, Train Loss: 0.0288
# Test Loss: 2.5312
#
# Epoch 182/200, Train Loss: 0.0251
# Test Loss: 2.5840
#
# Epoch 183/200, Train Loss: 0.0584
# Test Loss: 2.3001
#
# Epoch 184/200, Train Loss: 0.0500
# Test Loss: 2.3131
#
# Epoch 185/200, Train Loss: 0.0465
# Test Loss: 2.4373
#
# Epoch 186/200, Train Loss: 0.0262
# Test Loss: 2.4033
#
# Epoch 187/200, Train Loss: 0.0196
# Test Loss: 2.5848
#
# Epoch 188/200, Train Loss: 0.0155
# Test Loss: 2.4996
#
# Epoch 189/200, Train Loss: 0.0146
# Test Loss: 2.4926
#
# Epoch 190/200, Train Loss: 0.0263
# Test Loss: 2.0782
#
# Epoch 191/200, Train Loss: 0.0472
# Test Loss: 2.2909
#
# Epoch 192/200, Train Loss: 0.0450
# Test Loss: 2.3595
#
# Epoch 193/200, Train Loss: 0.0248
# Test Loss: 2.3761
#
# Epoch 194/200, Train Loss: 0.0249
# Test Loss: 2.5319
#
# Epoch 195/200, Train Loss: 0.0162
# Test Loss: 2.3937
#
# Epoch 196/200, Train Loss: 0.0138
# Test Loss: 2.4157
#
# Epoch 197/200, Train Loss: 0.0138
# Test Loss: 2.3346
#
# Epoch 198/200, Train Loss: 0.0147
# Test Loss: 2.5844
#
# Epoch 199/200, Train Loss: 0.0127
# Test Loss: 2.5477
#
# Epoch 200/200, Train Loss: 0.0119
# Test Loss: 2.5586

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Courbe de Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Classification

# %% [markdown]
# Au lieu de faire une régression, on va faire une classification.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

# %%
# Classe pour le modèle ViT
class ViTModel(nn.Module):
    def __init__(self, num_classes=200):  # Paramètre pour spécifier le nombre de classes
        super(ViTModel, self).__init__()
        # Exemple d'utilisation d'un modèle ViT pré-entrainé (par ex., de Hugging Face ou PyTorch)
        # Ici, on suppose l'utilisation d'un modèle préexistant, comme ViT-B/16 de Hugging Face
        self.vit = models.vit_b_16(pretrained=True)  # Charger le modèle ViT pré-entrainé
        
        # Remplacer la couche de classification pour correspondre au nombre de classes
        self.vit.head = nn.Linear(self.vit.head.in_features, num_classes)

    def forward(self, x):
        return self.vit(x)

# Classe pour entraîner et gérer le modèle
class ViTTrainer:
    def __init__(self, num_classes=200, lr=1e-4):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model = ViTModel(num_classes=num_classes).to(self.device)
        
        # Définir le critère de perte et l'optimiseur
        self.criterion = nn.CrossEntropyLoss()  # Utilisation de la CrossEntropyLoss pour la classification
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        
    def train(self, train_loader, num_epochs=10):
        self.model.train()  # Mettre le modèle en mode entraînement
        for epoch in range(num_epochs):
            running_loss = 0.0
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(self.device), labels.to(self.device)
                
                self.optimizer.zero_grad()  # Zéroiser les gradients
                
                outputs = self.model(inputs)  # Passer les entrées dans le modèle
                loss = self.criterion(outputs, labels)  # Calculer la perte
                
                loss.backward()  # Calculer les gradients
                self.optimizer.step()  # Mettre à jour les poids
                
                running_loss += loss.item()
            
            print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader)}")
    
    def evaluate(self, val_loader):
        self.model.eval()  # Mettre le modèle en mode évaluation
        correct = 0
        total = 0
        with torch.no_grad():  # Ne pas calculer les gradients pour l'évaluation
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(self.device), labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs, 1)  # Obtenir la classe avec la probabilité la plus élevée
                
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        accuracy = correct / total * 100
        print(f"Accuracy: {accuracy:.2f}%")

# %%
train_losses = []
test_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * xb.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}")
    
    # évaluation rapide sur test
    model.eval()
    with torch.no_grad():
        test_loss = 0.0
        for xb, yb in test_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            test_loss += criterion(pred, yb).item() * xb.size(0)
        test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print(f"Test Loss: {test_loss:.4f}\n")
# Out:
# Epoch 1/200, Train Loss: 0.0132
# Test Loss: 2.5141
#
# Epoch 2/200, Train Loss: 0.0119
# Test Loss: 2.4965
#
# Epoch 3/200, Train Loss: 0.0149
# Test Loss: 2.5709
#
# Epoch 4/200, Train Loss: 0.0165
# Test Loss: 2.3945
#
# Epoch 5/200, Train Loss: 0.0426
# Test Loss: 2.7406
#
# Epoch 6/200, Train Loss: 0.0309
# Test Loss: 2.4697
#
# Epoch 7/200, Train Loss: 0.0188
# Test Loss: 2.4739
#
# Epoch 8/200, Train Loss: 0.0138
# Test Loss: 2.4548
#
# Epoch 9/200, Train Loss: 0.0111
# Test Loss: 2.4102
#
# Epoch 10/200, Train Loss: 0.0103
# Test Loss: 2.4567
#
# Epoch 11/200, Train Loss: 0.0487
# Test Loss: 2.2159
#
# Epoch 12/200, Train Loss: 0.0402
# Test Loss: 2.7992
#
# Epoch 13/200, Train Loss: 0.0236
# Test Loss: 2.5268
#
# Epoch 14/200, Train Loss: 0.0166
# Test Loss: 2.5181
#
# Epoch 15/200, Train Loss: 0.0124
# Test Loss: 2.5226
#
# Epoch 16/200, Train Loss: 0.0706
# Test Loss: 2.3652
#
# Epoch 17/200, Train Loss: 0.0404
# Test Loss: 2.5763
#
# Epoch 18/200, Train Loss: 0.0366
# Test Loss: 2.4411
#
# Epoch 19/200, Train Loss: 0.0209
# Test Loss: 2.2994
#
# Epoch 20/200, Train Loss: 0.0137
# Test Loss: 2.3367
#
# Epoch 21/200, Train Loss: 0.0117
# Test Loss: 2.4075
#
# Epoch 22/200, Train Loss: 0.0105
# Test Loss: 2.3745
#
# Epoch 23/200, Train Loss: 0.0097
# Test Loss: 2.3191
#
# Epoch 24/200, Train Loss: 0.0105
# Test Loss: 2.3369
#
# Epoch 25/200, Train Loss: 0.0095
# Test Loss: 2.3123
#
# Epoch 26/200, Train Loss: 0.0086
# Test Loss: 2.2100
#
# Epoch 27/200, Train Loss: 0.0087
# Test Loss: 2.3135
#
# Epoch 28/200, Train Loss: 0.0248
# Test Loss: 2.2545
#
# Epoch 29/200, Train Loss: 0.0409
# Test Loss: 2.3716
#
# Epoch 30/200, Train Loss: 0.0360
# Test Loss: 2.5203
#
# Epoch 31/200, Train Loss: 0.0577
# Test Loss: 2.5950
#
# Epoch 32/200, Train Loss: 0.0407
# Test Loss: 2.6028
#
# Epoch 33/200, Train Loss: 0.0252
# Test Loss: 2.6215
#
# Epoch 34/200, Train Loss: 0.0175
# Test Loss: 2.5386
#
# Epoch 35/200, Train Loss: 0.0129
# Test Loss: 2.4989
#
# Epoch 36/200, Train Loss: 0.0109
# Test Loss: 2.5823
#
# Epoch 37/200, Train Loss: 0.0111
# Test Loss: 2.6236
#
# Epoch 38/200, Train Loss: 0.0099
# Test Loss: 2.6928
#
# Epoch 39/200, Train Loss: 0.0091
# Test Loss: 2.5676
#
# Epoch 40/200, Train Loss: 0.0087
# Test Loss: 2.4633
#
# Epoch 41/200, Train Loss: 0.0096
# Test Loss: 2.5050
#
# Epoch 42/200, Train Loss: 0.0085
# Test Loss: 2.5729
#
# Epoch 43/200, Train Loss: 0.0082
# Test Loss: 2.5539
#
# Epoch 44/200, Train Loss: 0.0081
# Test Loss: 2.5985
#
# Epoch 45/200, Train Loss: 0.0083
# Test Loss: 2.6409
#
# Epoch 46/200, Train Loss: 0.0088
# Test Loss: 2.5279
#
# Epoch 47/200, Train Loss: 0.0465
# Test Loss: 2.6844
#
# Epoch 48/200, Train Loss: 0.0725
# Test Loss: 2.5708
#
# Epoch 49/200, Train Loss: 0.0261
# Test Loss: 2.6350
#
# Epoch 50/200, Train Loss: 0.0229
# Test Loss: 2.3178
#
# Epoch 51/200, Train Loss: 0.0452
# Test Loss: 2.3401
#
# Epoch 52/200, Train Loss: 0.0377
# Test Loss: 2.4217
#
# Epoch 53/200, Train Loss: 0.0221
# Test Loss: 2.3726
#
# Epoch 54/200, Train Loss: 0.0184
# Test Loss: 2.6653
#
# Epoch 55/200, Train Loss: 0.0261
# Test Loss: 2.5197
#
# Epoch 56/200, Train Loss: 0.0187
# Test Loss: 2.6174
#
# Epoch 57/200, Train Loss: 0.0150
# Test Loss: 2.5509
#
# Epoch 58/200, Train Loss: 0.0128
# Test Loss: 2.5621
#
# Epoch 59/200, Train Loss: 0.0125
# Test Loss: 2.5172
#
# Epoch 60/200, Train Loss: 0.0088
# Test Loss: 2.5186
#
# Epoch 61/200, Train Loss: 0.0089
# Test Loss: 2.5920
#
# Epoch 62/200, Train Loss: 0.0075
# Test Loss: 2.5793
#
# Epoch 63/200, Train Loss: 0.0191
# Test Loss: 2.6372
#
# Epoch 64/200, Train Loss: 0.0273
# Test Loss: 2.4723
#
# Epoch 65/200, Train Loss: 0.0214
# Test Loss: 2.3724
#
# Epoch 66/200, Train Loss: 0.0103
# Test Loss: 2.3946
#
# Epoch 67/200, Train Loss: 0.0384
# Test Loss: 2.4745
#
# Epoch 68/200, Train Loss: 0.0189
# Test Loss: 2.5390
#
# Epoch 69/200, Train Loss: 0.0293
# Test Loss: 2.3980
#
# Epoch 70/200, Train Loss: 0.0327
# Test Loss: 2.3092
#
# Epoch 71/200, Train Loss: 0.0172
# Test Loss: 2.3413
#
# Epoch 72/200, Train Loss: 0.0110
# Test Loss: 2.2774
#
# Epoch 73/200, Train Loss: 0.0091
# Test Loss: 2.3112
#
# Epoch 74/200, Train Loss: 0.0092
# Test Loss: 2.2274
#
# Epoch 75/200, Train Loss: 0.0389
# Test Loss: 2.2052
#
# Epoch 76/200, Train Loss: 0.0281
# Test Loss: 2.2469
#
# Epoch 77/200, Train Loss: 0.0293
# Test Loss: 2.1637
#
# Epoch 78/200, Train Loss: 0.0252
# Test Loss: 2.2159
#
# Epoch 79/200, Train Loss: 0.0372
# Test Loss: 2.2878
#
# Epoch 80/200, Train Loss: 0.0314
# Test Loss: 2.2414
#
# Epoch 81/200, Train Loss: 0.0216
# Test Loss: 2.1455
#
# Epoch 82/200, Train Loss: 0.0128
# Test Loss: 2.0741
#
# Epoch 83/200, Train Loss: 0.0103
# Test Loss: 2.1388
#
# Epoch 84/200, Train Loss: 0.0089
# Test Loss: 2.1846
#
# Epoch 85/200, Train Loss: 0.0130
# Test Loss: 2.1544
#
# Epoch 86/200, Train Loss: 0.0182
# Test Loss: 2.1194
#
# Epoch 87/200, Train Loss: 0.0117
# Test Loss: 2.1496
#
# Epoch 88/200, Train Loss: 0.0081
# Test Loss: 2.1187
#
# Epoch 89/200, Train Loss: 0.0074
# Test Loss: 2.2106
#
# Epoch 90/200, Train Loss: 0.0072
# Test Loss: 2.2483
#
# Epoch 91/200, Train Loss: 0.0066
# Test Loss: 2.2646
#
# Epoch 92/200, Train Loss: 0.0064
# Test Loss: 2.1652
#
# Epoch 93/200, Train Loss: 0.0068
# Test Loss: 2.2113
#
# Epoch 94/200, Train Loss: 0.0166
# Test Loss: 2.3853
#
# Epoch 95/200, Train Loss: 0.0708
# Test Loss: 2.2256
#
# Epoch 96/200, Train Loss: 0.0399
# Test Loss: 2.2764
#
# Epoch 97/200, Train Loss: 0.0189
# Test Loss: 2.2306
#
# Epoch 98/200, Train Loss: 0.0124
# Test Loss: 2.2612
#
# Epoch 99/200, Train Loss: 0.0173
# Test Loss: 2.2932
#
# Epoch 100/200, Train Loss: 0.0129
# Test Loss: 2.3355
#
# Epoch 101/200, Train Loss: 0.0095
# Test Loss: 2.2029
#
# Epoch 102/200, Train Loss: 0.0111
# Test Loss: 2.1702
#
# Epoch 103/200, Train Loss: 0.0183
# Test Loss: 2.2799
#
# Epoch 104/200, Train Loss: 0.0248
# Test Loss: 2.0548
#
# Epoch 105/200, Train Loss: 0.0156
# Test Loss: 2.1746
#
# Epoch 106/200, Train Loss: 0.0097
# Test Loss: 2.1245
#
# Epoch 107/200, Train Loss: 0.0077
# Test Loss: 2.1800
#
# Epoch 108/200, Train Loss: 0.0066
# Test Loss: 2.1603
#
# Epoch 109/200, Train Loss: 0.0060
# Test Loss: 2.1761
#
# Epoch 110/200, Train Loss: 0.0063
# Test Loss: 2.2586
#
# Epoch 111/200, Train Loss: 0.0059
# Test Loss: 2.1165
#
# Epoch 112/200, Train Loss: 0.0060
# Test Loss: 2.1835
#
# Epoch 113/200, Train Loss: 0.0061
# Test Loss: 2.1884
#
# Epoch 114/200, Train Loss: 0.0058
# Test Loss: 2.3099
#
# Epoch 115/200, Train Loss: 0.0065
# Test Loss: 2.1341
#
# Epoch 116/200, Train Loss: 0.0071
# Test Loss: 1.9999
#
# Epoch 117/200, Train Loss: 0.0083
# Test Loss: 2.0902
#
# Epoch 118/200, Train Loss: 0.0118
# Test Loss: 1.9602
#
# Epoch 119/200, Train Loss: 0.0544
# Test Loss: 1.9887
#
# Epoch 120/200, Train Loss: 0.0679
# Test Loss: 2.0856
#
# Epoch 121/200, Train Loss: 0.0697
# Test Loss: 2.3180
#
# Epoch 122/200, Train Loss: 0.0434
# Test Loss: 2.0789
#
# Epoch 123/200, Train Loss: 0.0389
# Test Loss: 2.2712
#
# Epoch 124/200, Train Loss: 0.0300
# Test Loss: 2.1514
#
# Epoch 125/200, Train Loss: 0.0263
# Test Loss: 2.1345
#
# Epoch 126/200, Train Loss: 0.0172
# Test Loss: 2.0694
#
# Epoch 127/200, Train Loss: 0.0136
# Test Loss: 2.0836
#
# Epoch 128/200, Train Loss: 0.0191
# Test Loss: 2.1059
#
# Epoch 129/200, Train Loss: 0.0231
# Test Loss: 2.0217
#
# Epoch 130/200, Train Loss: 0.0184
# Test Loss: 2.6132
#
# Epoch 131/200, Train Loss: 0.0347
# Test Loss: 2.2095
#
# Epoch 132/200, Train Loss: 0.0139
# Test Loss: 2.1980
#
# Epoch 133/200, Train Loss: 0.0152
# Test Loss: 2.1224
#
# Epoch 134/200, Train Loss: 0.0103
# Test Loss: 2.3070
#
# Epoch 135/200, Train Loss: 0.0083
# Test Loss: 2.1587
#
# Epoch 136/200, Train Loss: 0.0073
# Test Loss: 2.2863
#
# Epoch 137/200, Train Loss: 0.0066
# Test Loss: 2.0535
#
# Epoch 138/200, Train Loss: 0.0060
# Test Loss: 2.1103
#
# Epoch 139/200, Train Loss: 0.0059
# Test Loss: 2.1813
#
# Epoch 140/200, Train Loss: 0.0060
# Test Loss: 2.1616
#
# Epoch 141/200, Train Loss: 0.0237
# Test Loss: 2.0593
#
# Epoch 142/200, Train Loss: 0.0492
# Test Loss: 2.5066
#
# Epoch 143/200, Train Loss: 0.0171
# Test Loss: 2.2409
#
# Epoch 144/200, Train Loss: 0.0144
# Test Loss: 2.2020
#
# Epoch 145/200, Train Loss: 0.0093
# Test Loss: 2.1688
#
# Epoch 146/200, Train Loss: 0.0079
# Test Loss: 2.2255
#
# Epoch 147/200, Train Loss: 0.0097
# Test Loss: 2.0278
#
# Epoch 148/200, Train Loss: 0.0209
# Test Loss: 2.1247
#
# Epoch 149/200, Train Loss: 0.0318
# Test Loss: 2.0519
#
# Epoch 150/200, Train Loss: 0.0268
# Test Loss: 1.9728
#
# Epoch 151/200, Train Loss: 0.0118
# Test Loss: 2.0921
#
# Epoch 152/200, Train Loss: 0.0083
# Test Loss: 2.0845
#
# Epoch 153/200, Train Loss: 0.0070
# Test Loss: 2.0672
#
# Epoch 154/200, Train Loss: 0.0077
# Test Loss: 2.1422
#
# Epoch 155/200, Train Loss: 0.0059
# Test Loss: 2.1854
#
# Epoch 156/200, Train Loss: 0.0054
# Test Loss: 2.1416
#
# Epoch 157/200, Train Loss: 0.0055
# Test Loss: 2.1505
#
# Epoch 158/200, Train Loss: 0.0081
# Test Loss: 2.1905
#
# Epoch 159/200, Train Loss: 0.0060
# Test Loss: 2.1523
#
# Epoch 160/200, Train Loss: 0.0052
# Test Loss: 2.1357
#
# Epoch 161/200, Train Loss: 0.0051
# Test Loss: 2.2381
#
# Epoch 162/200, Train Loss: 0.0054
# Test Loss: 2.1814
#
# Epoch 163/200, Train Loss: 0.0056
# Test Loss: 1.9847
#
# Epoch 164/200, Train Loss: 0.0059
# Test Loss: 2.1831
#
# Epoch 165/200, Train Loss: 0.0072
# Test Loss: 2.2505
#
# Epoch 166/200, Train Loss: 0.0170
# Test Loss: 2.1529
#
# Epoch 167/200, Train Loss: 0.0412
# Test Loss: 2.1374
#
# Epoch 168/200, Train Loss: 0.0237
# Test Loss: 2.1571
#
# Epoch 169/200, Train Loss: 0.0148
# Test Loss: 1.9915
#
# Epoch 170/200, Train Loss: 0.0087
# Test Loss: 2.0549
#
# Epoch 171/200, Train Loss: 0.0062
# Test Loss: 2.0612
#
# Epoch 172/200, Train Loss: 0.0053
# Test Loss: 2.0097
#
# Epoch 173/200, Train Loss: 0.0046
# Test Loss: 2.0723
#
# Epoch 174/200, Train Loss: 0.0044
# Test Loss: 2.1082
#
# Epoch 175/200, Train Loss: 0.0045
# Test Loss: 2.1045
#
# Epoch 176/200, Train Loss: 0.0040
# Test Loss: 2.1055
#
# Epoch 177/200, Train Loss: 0.0039
# Test Loss: 2.0851
#
# Epoch 178/200, Train Loss: 0.0040
# Test Loss: 2.0611
#
# Epoch 179/200, Train Loss: 0.0042
# Test Loss: 2.1101
#
# Epoch 180/200, Train Loss: 0.0087
# Test Loss: 2.0214
#
# Epoch 181/200, Train Loss: 0.0052
# Test Loss: 2.0607
#
# Epoch 182/200, Train Loss: 0.0044
# Test Loss: 2.1361
#
# Epoch 183/200, Train Loss: 0.0042
# Test Loss: 2.1504
#
# Epoch 184/200, Train Loss: 0.0043
# Test Loss: 2.0840
#
# Epoch 185/200, Train Loss: 0.0046
# Test Loss: 2.1209
#
# Epoch 186/200, Train Loss: 0.0046
# Test Loss: 2.0628
#
# Epoch 187/200, Train Loss: 0.0046
# Test Loss: 2.0504
#
# Epoch 188/200, Train Loss: 0.0046
# Test Loss: 2.1380
#
# Epoch 189/200, Train Loss: 0.0101
# Test Loss: 2.3475
#
# Epoch 190/200, Train Loss: 0.0680
# Test Loss: 2.3362
#
# Epoch 191/200, Train Loss: 0.0369
# Test Loss: 2.4384
#
# Epoch 192/200, Train Loss: 0.0231
# Test Loss: 2.0380
#
# Epoch 193/200, Train Loss: 0.0204
# Test Loss: 2.1604
#
# Epoch 194/200, Train Loss: 0.0101
# Test Loss: 2.1235
#
# Epoch 195/200, Train Loss: 0.0167
# Test Loss: 2.1481
#
# Epoch 196/200, Train Loss: 0.0107
# Test Loss: 2.2378
#
# Epoch 197/200, Train Loss: 0.0079
# Test Loss: 2.2152
#
# Epoch 198/200, Train Loss: 0.0116
# Test Loss: 2.1660
#
# Epoch 199/200, Train Loss: 0.0061
# Test Loss: 2.1283
#
# Epoch 200/200, Train Loss: 0.0051
# Test Loss: 2.1298

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Courbe de Loss")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-234665988.py in <cell line: 0>()
#       2
#       3 plt.figure(figsize=(8,5))
# ----> 4 plt.plot(train_losses, label="Train Loss")
#       5 plt.plot(test_losses, label="Test Loss")
#       6 plt.xlabel("Epoch")
#
# NameError: name 'train_losses' is not defined

# %% [markdown]
# ## +++

# %%
# --- Nettoyage des sentinelles dans les images ---
sentinel_threshold = -99

X_train[X_train < sentinel_threshold] = np.nan
X_test[X_test < sentinel_threshold] = np.nan

# %%
y_train = infos_train['ZPHOT']
y_test = infos_test['ZSPEC']

# %%
train_losses = []
test_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * xb.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}")
    
    # évaluation rapide sur test
    model.eval()
    with torch.no_grad():
        test_loss = 0.0
        for xb, yb in test_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            test_loss += criterion(pred, yb).item() * xb.size(0)
        test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print(f"Test Loss: {test_loss:.4f}\n")
# Out:
# Epoch 1/200, Train Loss: 0.7653
# Test Loss: 2.3055
#
# Epoch 2/200, Train Loss: 0.5992
# Test Loss: 2.5503
#
# Epoch 3/200, Train Loss: 0.5615
# Test Loss: 2.2563
#
# Epoch 4/200, Train Loss: 0.5255
# Test Loss: 2.3592
#
# Epoch 5/200, Train Loss: 0.4944
# Test Loss: 2.1725
#
# Epoch 6/200, Train Loss: 0.4659
# Test Loss: 2.2048
#
# Epoch 7/200, Train Loss: 0.4529
# Test Loss: 2.1188
#
# Epoch 8/200, Train Loss: 0.4282
# Test Loss: 2.2796
#
# Epoch 9/200, Train Loss: 0.3992
# Test Loss: 2.1141
#
# Epoch 10/200, Train Loss: 0.3851
# Test Loss: 2.3707
#
# Epoch 11/200, Train Loss: 0.3695
# Test Loss: 2.5828
#
# Epoch 12/200, Train Loss: 0.3574
# Test Loss: 2.5462
#
# Epoch 13/200, Train Loss: 0.3389
# Test Loss: 2.8784
#
# Epoch 14/200, Train Loss: 0.3257
# Test Loss: 2.8081
#
# Epoch 15/200, Train Loss: 0.3062
# Test Loss: 3.0058
#
# Epoch 16/200, Train Loss: 0.2940
# Test Loss: 2.7186
#
# Epoch 17/200, Train Loss: 0.2834
# Test Loss: 2.6197
#
# Epoch 18/200, Train Loss: 0.2667
# Test Loss: 2.9420
#
# Epoch 19/200, Train Loss: 0.2589
# Test Loss: 2.9284
#
# Epoch 20/200, Train Loss: 0.2499
# Test Loss: 3.0769
#
# Epoch 21/200, Train Loss: 0.2406
# Test Loss: 3.7132
#
# Epoch 22/200, Train Loss: 0.2429
# Test Loss: 2.8695
#
# Epoch 23/200, Train Loss: 0.2353
# Test Loss: 3.0031
#
# Epoch 24/200, Train Loss: 0.2217
# Test Loss: 2.6699
#
# Epoch 25/200, Train Loss: 0.2127
# Test Loss: 2.8176
#
# Epoch 26/200, Train Loss: 0.1882
# Test Loss: 2.7295
#
# Epoch 27/200, Train Loss: 0.1916
# Test Loss: 2.7187
#
# Epoch 28/200, Train Loss: 0.1863
# Test Loss: 2.4571
#
# Epoch 29/200, Train Loss: 0.1825
# Test Loss: 2.8034
#
# Epoch 30/200, Train Loss: 0.1698
# Test Loss: 2.5589
#
# Epoch 31/200, Train Loss: 0.1672
# Test Loss: 2.6992
#
# Epoch 32/200, Train Loss: 0.1643
# Test Loss: 2.5509
#
# Epoch 33/200, Train Loss: 0.1731
# Test Loss: 2.6038
#
# Epoch 34/200, Train Loss: 0.1563
# Test Loss: 2.5773
#
# Epoch 35/200, Train Loss: 0.1574
# Test Loss: 2.2014
#
# Epoch 36/200, Train Loss: 0.1394
# Test Loss: 2.3061
#
# Epoch 37/200, Train Loss: 0.1405
# Test Loss: 2.5180
#
# Epoch 38/200, Train Loss: 0.1666
# Test Loss: 2.4144
#
# Epoch 39/200, Train Loss: 0.1829
# Test Loss: 2.2775
#
# Epoch 40/200, Train Loss: 0.2779
# Test Loss: 2.4327
#
# Epoch 41/200, Train Loss: 0.1649
# Test Loss: 2.4731
#
# Epoch 42/200, Train Loss: 0.1474
# Test Loss: 2.5460
#
# Epoch 43/200, Train Loss: 0.1422
# Test Loss: 2.5460
#
# Epoch 44/200, Train Loss: 0.1166
# Test Loss: 2.8370
#
# Epoch 45/200, Train Loss: 0.1257
# Test Loss: 2.5428
#
# Epoch 46/200, Train Loss: 0.1121
# Test Loss: 2.6156
#
# Epoch 47/200, Train Loss: 0.1158
# Test Loss: 2.6512
#
# Epoch 48/200, Train Loss: 0.1082
# Test Loss: 2.5715
#
# Epoch 49/200, Train Loss: 0.1009
# Test Loss: 2.5812
#
# Epoch 50/200, Train Loss: 0.1216
# Test Loss: 2.3908
#
# Epoch 51/200, Train Loss: 0.1155
# Test Loss: 2.4108
#
# Epoch 52/200, Train Loss: 0.1147
# Test Loss: 2.4169
#
# Epoch 53/200, Train Loss: 0.1121
# Test Loss: 2.5425
#
# Epoch 54/200, Train Loss: 0.1014
# Test Loss: 2.5912
#
# Epoch 55/200, Train Loss: 0.0992
# Test Loss: 2.7905
#
# Epoch 56/200, Train Loss: 0.0825
# Test Loss: 2.4536
#
# Epoch 57/200, Train Loss: 0.0916
# Test Loss: 2.4620
#
# Epoch 58/200, Train Loss: 0.1050
# Test Loss: 2.7503
#
# Epoch 59/200, Train Loss: 0.1107
# Test Loss: 2.4656
#
# Epoch 60/200, Train Loss: 0.0979
# Test Loss: 2.4551
#
# Epoch 61/200, Train Loss: 0.0840
# Test Loss: 2.3132
#
# Epoch 62/200, Train Loss: 0.0813
# Test Loss: 2.4511
#
# Epoch 63/200, Train Loss: 0.0824
# Test Loss: 2.3783
#
# Epoch 64/200, Train Loss: 0.0827
# Test Loss: 2.4326
#
# Epoch 65/200, Train Loss: 0.1014
# Test Loss: 2.3065
#
# Epoch 66/200, Train Loss: 0.0836
# Test Loss: 2.2113
#
# Epoch 67/200, Train Loss: 0.0745
# Test Loss: 2.3427
#
# Epoch 68/200, Train Loss: 0.0690
# Test Loss: 2.4108
#
# Epoch 69/200, Train Loss: 0.0768
# Test Loss: 2.0435
#
# Epoch 70/200, Train Loss: 0.0813
# Test Loss: 2.1082
#
# Epoch 71/200, Train Loss: 0.0638
# Test Loss: 2.1119
#
# Epoch 72/200, Train Loss: 0.0776
# Test Loss: 2.1139
#
# Epoch 73/200, Train Loss: 0.0709
# Test Loss: 2.1203
#
# Epoch 74/200, Train Loss: 0.0697
# Test Loss: 2.1576
#
# Epoch 75/200, Train Loss: 0.1029
# Test Loss: 1.8709
#
# Epoch 76/200, Train Loss: 0.0908
# Test Loss: 1.9801
#
# Epoch 77/200, Train Loss: 0.0788
# Test Loss: 2.1583
#
# Epoch 78/200, Train Loss: 0.0784
# Test Loss: 1.8333
#
# Epoch 79/200, Train Loss: 0.0605
# Test Loss: 1.7658
#
# Epoch 80/200, Train Loss: 0.0524
# Test Loss: 1.8271
#
# Epoch 81/200, Train Loss: 0.0670
# Test Loss: 1.9498
#
# Epoch 82/200, Train Loss: 0.0611
# Test Loss: 1.9452
#
# Epoch 83/200, Train Loss: 0.0739
# Test Loss: 2.2968
#
# Epoch 84/200, Train Loss: 0.0601
# Test Loss: 2.3220
#
# Epoch 85/200, Train Loss: 0.0620
# Test Loss: 2.1940
#
# Epoch 86/200, Train Loss: 0.0804
# Test Loss: 1.8715
#
# Epoch 87/200, Train Loss: 0.0742
# Test Loss: 1.9577
#
# Epoch 88/200, Train Loss: 0.0671
# Test Loss: 2.0273
#
# Epoch 89/200, Train Loss: 0.0576
# Test Loss: 2.1451
#
# Epoch 90/200, Train Loss: 0.0732
# Test Loss: 2.0234
#
# Epoch 91/200, Train Loss: 0.0500
# Test Loss: 2.0032
#
# Epoch 92/200, Train Loss: 0.0430
# Test Loss: 1.8861
#
# Epoch 93/200, Train Loss: 0.0760
# Test Loss: 2.1415
#
# Epoch 94/200, Train Loss: 0.0861
# Test Loss: 2.1243
#
# Epoch 95/200, Train Loss: 0.0589
# Test Loss: 1.9815
#
# Epoch 96/200, Train Loss: 0.0467
# Test Loss: 1.9839
#
# Epoch 97/200, Train Loss: 0.0453
# Test Loss: 1.9609
#
# Epoch 98/200, Train Loss: 0.0484
# Test Loss: 1.8462
#
# Epoch 99/200, Train Loss: 0.0513
# Test Loss: 2.0188
#
# Epoch 100/200, Train Loss: 0.0589
# Test Loss: 2.0328
#
# Epoch 101/200, Train Loss: 0.0464
# Test Loss: 2.1551
#
# Epoch 102/200, Train Loss: 0.0387
# Test Loss: 2.0558
#
# Epoch 103/200, Train Loss: 0.0534
# Test Loss: 2.5574
#
# Epoch 104/200, Train Loss: 0.1280
# Test Loss: 1.8340
#
# Epoch 105/200, Train Loss: 0.0660
# Test Loss: 1.6990
#
# Epoch 106/200, Train Loss: 0.0741
# Test Loss: 2.1737
#
# Epoch 107/200, Train Loss: 0.0485
# Test Loss: 2.0136
#
# Epoch 108/200, Train Loss: 0.0493
# Test Loss: 2.0314
#
# Epoch 109/200, Train Loss: 0.0572
# Test Loss: 1.8992
#
# Epoch 110/200, Train Loss: 0.0491
# Test Loss: 1.8745
#
# Epoch 111/200, Train Loss: 0.0475
# Test Loss: 1.9037
#
# Epoch 112/200, Train Loss: 0.0526
# Test Loss: 2.2725
#
# Epoch 113/200, Train Loss: 0.0417
# Test Loss: 2.1659
#
# Epoch 114/200, Train Loss: 0.0564
# Test Loss: 2.1675
#
# Epoch 115/200, Train Loss: 0.0382
# Test Loss: 2.0505
#
# Epoch 116/200, Train Loss: 0.0433
# Test Loss: 1.9694
#
# Epoch 117/200, Train Loss: 0.0389
# Test Loss: 2.2975
#
# Epoch 118/200, Train Loss: 0.0685
# Test Loss: 2.2124
#
# Epoch 119/200, Train Loss: 0.0612
# Test Loss: 2.1266
#
# Epoch 120/200, Train Loss: 0.0459
# Test Loss: 2.3067
#
# Epoch 121/200, Train Loss: 0.0470
# Test Loss: 2.2548
#
# Epoch 122/200, Train Loss: 0.0744
# Test Loss: 2.1300
#
# Epoch 123/200, Train Loss: 0.0639
# Test Loss: 2.2530
#
# Epoch 124/200, Train Loss: 0.0689
# Test Loss: 2.1121
#
# Epoch 125/200, Train Loss: 0.0474
# Test Loss: 1.9464
#
# Epoch 126/200, Train Loss: 0.0515
# Test Loss: 1.9834
#
# Epoch 127/200, Train Loss: 0.0396
# Test Loss: 1.9124
#
# Epoch 128/200, Train Loss: 0.0455
# Test Loss: 2.0927
#
# Epoch 129/200, Train Loss: 0.0372
# Test Loss: 1.8650
#
# Epoch 130/200, Train Loss: 0.0332
# Test Loss: 1.8723
#
# Epoch 131/200, Train Loss: 0.0752
# Test Loss: 2.1400
#
# Epoch 132/200, Train Loss: 0.0540
# Test Loss: 2.1329
#
# Epoch 133/200, Train Loss: 0.0417
# Test Loss: 2.1298
#
# Epoch 134/200, Train Loss: 0.0329
# Test Loss: 1.9676
#
# Epoch 135/200, Train Loss: 0.0317
# Test Loss: 1.8215
#
# Epoch 136/200, Train Loss: 0.0361
# Test Loss: 1.8623
#
# Epoch 137/200, Train Loss: 0.0404
# Test Loss: 2.0074
#
# Epoch 138/200, Train Loss: 0.0792
# Test Loss: 1.7953
#
# Epoch 139/200, Train Loss: 0.0693
# Test Loss: 1.5964
#
# Epoch 140/200, Train Loss: 0.0502
# Test Loss: 1.7012
#
# Epoch 141/200, Train Loss: 0.0548
# Test Loss: 1.9440
#
# Epoch 142/200, Train Loss: 0.0398
# Test Loss: 1.8756
#
# Epoch 143/200, Train Loss: 0.0412
# Test Loss: 1.8983
#
# Epoch 144/200, Train Loss: 0.0366
# Test Loss: 1.5667
#
# Epoch 145/200, Train Loss: 0.0448
# Test Loss: 1.6886
#
# Epoch 146/200, Train Loss: 0.0676
# Test Loss: 1.8304
#
# Epoch 147/200, Train Loss: 0.0650
# Test Loss: 1.5876
#
# Epoch 148/200, Train Loss: 0.0410
# Test Loss: 1.6611
#
# Epoch 149/200, Train Loss: 0.0346
# Test Loss: 1.9605
#
# Epoch 150/200, Train Loss: 0.0372
# Test Loss: 1.8900
#
# Epoch 151/200, Train Loss: 0.0360
# Test Loss: 1.7753
#
# Epoch 152/200, Train Loss: 0.0313
# Test Loss: 1.8996
#
# Epoch 153/200, Train Loss: 0.0362
# Test Loss: 1.8863
#
# Epoch 154/200, Train Loss: 0.0389
# Test Loss: 2.0196
#
# Epoch 155/200, Train Loss: 0.0482
# Test Loss: 1.9039
#
# Epoch 156/200, Train Loss: 0.0327
# Test Loss: 1.8259
#
# Epoch 157/200, Train Loss: 0.0355
# Test Loss: 1.7225
#
# Epoch 158/200, Train Loss: 0.0382
# Test Loss: 2.0794
#
# Epoch 159/200, Train Loss: 0.0592
# Test Loss: 2.1431
#
# Epoch 160/200, Train Loss: 0.0555
# Test Loss: 2.0764
#
# Epoch 161/200, Train Loss: 0.0292
# Test Loss: 2.1678
#
# Epoch 162/200, Train Loss: 0.0248
# Test Loss: 2.1632
#
# Epoch 163/200, Train Loss: 0.0279
# Test Loss: 2.2456
#
# Epoch 164/200, Train Loss: 0.0401
# Test Loss: 2.3520
#
# Epoch 165/200, Train Loss: 0.0444
# Test Loss: 2.0147
#
# Epoch 166/200, Train Loss: 0.0575
# Test Loss: 2.0041
#
# Epoch 167/200, Train Loss: 0.0590
# Test Loss: 2.2004
#
# Epoch 168/200, Train Loss: 0.0353
# Test Loss: 1.9716
#
# Epoch 169/200, Train Loss: 0.0265
# Test Loss: 1.7460
#
# Epoch 170/200, Train Loss: 0.0238
# Test Loss: 1.7328
#
# Epoch 171/200, Train Loss: 0.0222
# Test Loss: 1.6746
#
# Epoch 172/200, Train Loss: 0.0209
# Test Loss: 1.6587
#
# Epoch 173/200, Train Loss: 0.0207
# Test Loss: 1.7617
#
# Epoch 174/200, Train Loss: 0.0383
# Test Loss: 1.8100
#
# Epoch 175/200, Train Loss: 0.0359
# Test Loss: 1.8620
#
# Epoch 176/200, Train Loss: 0.0516
# Test Loss: 2.1055
#
# Epoch 177/200, Train Loss: 0.0370
# Test Loss: 1.9611
#
# Epoch 178/200, Train Loss: 0.0321
# Test Loss: 2.0816
#
# Epoch 179/200, Train Loss: 0.0590
# Test Loss: 2.2020
#
# Epoch 180/200, Train Loss: 0.0382
# Test Loss: 2.2299
#
# Epoch 181/200, Train Loss: 0.0352
# Test Loss: 2.0669
#
# Epoch 182/200, Train Loss: 0.0251
# Test Loss: 1.9772
#
# Epoch 183/200, Train Loss: 0.0242
# Test Loss: 1.9746
#
# Epoch 184/200, Train Loss: 0.0194
# Test Loss: 1.9046
#
# Epoch 185/200, Train Loss: 0.0191
# Test Loss: 1.9071
#
# Epoch 186/200, Train Loss: 0.0268
# Test Loss: 1.9745
#
# Epoch 187/200, Train Loss: 0.0697
# Test Loss: 2.0870
#
# Epoch 188/200, Train Loss: 0.0377
# Test Loss: 2.1712
#
# Epoch 189/200, Train Loss: 0.0301
# Test Loss: 1.7851
#
# Epoch 190/200, Train Loss: 0.0420
# Test Loss: 2.0277
#
# Epoch 191/200, Train Loss: 0.0243
# Test Loss: 2.0295
#
# Epoch 192/200, Train Loss: 0.0255
# Test Loss: 1.8616
#
# Epoch 193/200, Train Loss: 0.0316
# Test Loss: 2.3704
#
# Epoch 194/200, Train Loss: 0.0665
# Test Loss: 2.1028
#
# Epoch 195/200, Train Loss: 0.0355
# Test Loss: 1.7907
#
# Epoch 196/200, Train Loss: 0.0274
# Test Loss: 1.8069
#
# Epoch 197/200, Train Loss: 0.0204
# Test Loss: 1.8133
#
# Epoch 198/200, Train Loss: 0.0182
# Test Loss: 1.8427
#
# Epoch 199/200, Train Loss: 0.0173
# Test Loss: 1.8588
#
# Epoch 200/200, Train Loss: 0.0205
# Test Loss: 2.0224

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Courbe de Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
model.eval()
mae_total = 0.0

with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        pred = model(xb)
        mae_total += torch.abs(pred - yb).sum().item()

mae_final = mae_total / len(test_loader.dataset)

print(f"\nMAE finale sur le test set : {mae_final:.5f}")
# Out:
# MAE finale sur le test set : 0.83350

# %%
model.eval()

z_pred_list = []
z_true_list = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        pred = model(xb)

        z_pred_list.append(pred.cpu().numpy())
        z_true_list.append(yb.numpy())

# Concaténer tout
z_pred = np.concatenate(z_pred_list).flatten()
z_true = np.concatenate(z_true_list).flatten()

# --- Calcul des métriques photo-z ---

delta_z = z_pred - z_true
delta_z_norm = delta_z / (1 + z_true)

# Sigma NMAD
sigma_nmad = 1.48 * np.median(
    np.abs(delta_z_norm - np.median(delta_z_norm))
)

# Biais
bias = np.mean(delta_z_norm)

# Taux d'outliers (|Δz_norm| > 0.15)
outlier_mask = np.abs(delta_z_norm) > 0.15
tau = np.sum(outlier_mask) / len(delta_z_norm)

print("\n===== MÉTRIQUES PHOTO-Z =====")
print(f"Sigma_NMAD : {sigma_nmad:.5f}")
print(f"Biais      : {bias:.5f}")
print(f"(outliers >0.15) : {tau:.5f}")
# Out:
# ===== MÉTRIQUES PHOTO-Z =====
# Sigma_NMAD : 0.27739
# Biais      : 0.20737
# Tau (outliers >0.15) : 0.59259
